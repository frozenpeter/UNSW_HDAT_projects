# %% [markdown]
# <a href="https://colab.research.google.com/github/CBDRH-HDAT9500/final-assignment/blob/main/FA_NamesSurnames.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![alt text](https://drive.google.com/uc?export=view&id=1DXUVHxd4t15mfuqMgMCLnsP4jWVI5EWz)
#
# ---
#
# <br>
# © 2024 Copyright The University of New South Wales - CRICOS 00098G
#
# **Author**: Oscar Perez-Concha.
#
# **Communications**: If you have any questions, please email Oscar at: o.perezconcha@unsw.edu.au

# %% [markdown]
# ---

# %% [markdown]
# # Project 1: Redesigning Discharge

# %% [markdown]
# ---

# %% [markdown]
# #####################################################################################
#
# Double-click to write down your name and surname.
#
# **zID:** z5037788
#
# **Name:** Zhenyu
#
# **Surname:** Zhang
#
# **Honour Pledge** <p>
#
# Declaration: <p>
#
#
# I declare that this assessment item is my own work, except where acknowledged, and has not been submitted for academic credit elsewhere or previously, or produced independently of this course (e.g. for a third party such as your place of employment) and acknowledge that the assessor of this item may, for the purpose of assessing this item:
#
# 1. Reproduce this assessment item and provide a copy to another member of the University; and/or
#
# 2. Communicate a copy of this assessment item to a plagiarism checking service (which may then retain a copy of the assessment item on its database for the purpose of future plagiarism checking).
#
# **By writing your zID, name and surname above, you certify that you have read and agreed to the honour pledge.**
#
# #####################################################################################

# %% [markdown]
# #####################################################################################
#
# Double-click to write down your name and surname.
#
# **Name 2 and Surname 2:** Zhenyu Zhang
#
# **Honour Pledge** <p>
#
#
# Declaration: <p>
#
#
# I declare that this assessment item is my own work, except where acknowledged, and has not been submitted for academic credit elsewhere or previously, or produced independently of this course (e.g. for a third party such as your place of employment) and acknowledge that the assessor of this item may, for the purpose of assessing this item:
#
# 1. Reproduce this assessment item and provide a copy to another member of the University; and/or
#
# 2. Communicate a copy of this assessment item to a plagiarism checking service (which may then retain a copy of the assessment item on its database for the purpose of future plagiarism checking).
#
# **By wrting you name and surname above, you certify that you have read and agreed to the honour pledge.**
#
# #####################################################################################

# %% [markdown]
# ---

# %% [markdown]
# ---
# # 1.  Health Data Science Scenario

# %% [markdown]
# ## 1.1. Background
#
# Our hospital has been very proactive in analysing data from its Electronic Medical Records (EMR). Through this analysis, they have made some interesting discoveries.
#
# They identified that readmitted patients are not only those who were sicker during their first admission but also those with less support or medical follow-up after discharge. Readmitted patients experienced high levels of emotional stress and were at a significantly higher risk of acquiring new infections while in the hospital.
#
# Readmissions are highly costly. Patients who were readmitted for the reasons mentioned above tended to be sicker than during their first admission, and their length of stay was significantly longer.

# %% [markdown]
# ---

# %% [markdown]
# ## 1.2. Pilot program: "Redesigning Discharge"

# %% [markdown]
# Our hospital is going to implement a pilot program named "Redesigning Discharge", which involves a specialised unit that coordinates patients' discharges.
#
# This specialised unit is composed of a team of doctors, nurses, physiotherapists, and occupational therapists.
#
# The program consists of two main innovations:
#
# 1.   At the point of discharge, doctors will conduct an assessment to determine whether the patient is at risk of readmission within 30 days using:
#
#   a. Their own experience.
#
#   b. A new predictive algorithm that we are going to develop.
#
# 2.   If the answer to question one is 'yes'—that is, there is a risk of readmission to the hospital within 30 days of discharge—a new discharge plan will be put in place. This plan involves a program in which a team of nurses, physiotherapists, and occupational therapists will visit patients at their residence. The frequency of these visits, determined by an assessment conducted prior to discharge, averages about three visits per patient.
#
# Among other tasks, the team's responsibilities will include ensuring proper wound healing, checking medication compliance, coordinating with a general practitioner or the medical team at the intermediate facility, and assessing the patient's ability to perform basic daily activities such as navigating their environment, using the toilet, and showering. Furthermore, the specialised unit maintains regular telephone contact with patients to monitor their well-being. Patients are also encouraged to reach out to the unit if they need any assistance.

# %% [markdown]
# ---

# %% [markdown]
# ## 1.3. Budget

# %% [markdown]
# In terms of budget:
#
# 1. The average cost of a day in the hospital is 5,000 dollars; readmitted patients tend to stay for an average of 3 days.
#
# 2. An intervention by the specialized unit costs, on average, $3,000. This amount includes the cost of the average number of visits per patient, which is three visits.

# %% [markdown]
# ---

# %% [markdown]
# ## 1.4. Aims

# %% [markdown]
# Our research aims to address the following questions:
#
# 1. Can we develop a predictive algorithm that can determine the probability of a patient's readmission within 30 days after their discharge?
#
# 2. How can we effectively communicate the performance and benefits of this algorithm to hospital managers, enabling them to make an informed decision about its implementation?
#
# The main challenge we face is not only the development of an effective predictive algorithm, but also explaining its complexities in a clear, digestible manner for non-technical decision-makers.

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 1.5. Instructions
#
# 1.  We aim to develop a predictive model to forecast hospital readmissions within 30 days of discharge.
#
# > Consider the next points:
#
# > The predictive model will be run just prior to discharge, before a decision is made regarding the need for the specialised unit.
#
# > This forecast will primarily aid doctors and other clinicians in making a final decision about whether a patient will need the specialised unit.
#
# > We plan to use historical data from the hospital for this purpose.
#
# 2. Review the research questions and make the appropriate decisions for building this predictive model, in accordance with the research question text.
#
# 3. Thoroughly review and study the data provided.
#
# 4. Given that the hospital has already provided the data, we'll bypass the following steps in the health data science workflow (refer to the image below): Step 3 and substeps 3a,3b,3c,3d,3e: Data Gathering.
#
# 5. In Step 4, substep 4a (Data visualization), visualize the data in your drafts, but do not include the graphs in your final submission.
#
# 6. The hospital aims to capture as many "readmissions" as possible (true positives), even if this moderately increases the number of false positives within reason (i.e., patients not at risk of readmission classified as such). However, be mindful that the hospital does not have unlimited resources. An excessive number of patients identified as at-risk could inflate the operational costs of the specialised unit beyond sustainable levels.
#
# 7. The data scientists at the hospital have asked that you only consider the Logistic Regression and Random Forest machine learning techniques.
#
# 8. Design various machine learning algorithms with different hyperparameters. Select one and provide a rationale for your choice.
#
# 9. Use the **classification_report and confusion matrix metrics** for model evaluation. If you use other metrics such as the ROC curve, do not include them in your final submission.
#
# 10. **Justification for your decisions is crucial. Provide a one or two sentence explanation for each section preceding the relevant Python code block using "Text" cells. There is a word limit for these sections.**
#
# 11. **Clear labels for printed results and briefly detail the steps followed.Marks will be deducted if this instruction is not followed.**
#
# 12. **Comment and document every line of code, as this will likely serve as a foundation for team-based algorithm development in the future. Marks will be deducted if this instruction is not followed. You are encouraged to use "Sanity Checks" during the construction of the algorithms. Please do not include them in your final submission. Marks will be deducted if this instruction is not followed**
#
# 13. Ensure that the number of Python code lines does not exceed the specified limit. A Python line refers to a single line of code in a Python script or program. It is defined as any line that contains executable code. We are excuding blank lines and comments (precedeed by #).
#
# 14. Format: Jupyter Notebook.
#
# 15. Programming Language: Python.
#
# 16. Submission: Upload the Jupyter Notebook to the designated section in OpenLearning. Submissions will close precisely at the deadline.
#
# 17. Only submit the final version of your document.
#
# 18. Include your first and last names in the document's title. For example: Final-Assignment-z8888888-Anne-Ross.ipynb
#
# 19. Marks: Questions 4 and 6: 2 marks. The rest of questions: 1 mark.
#
# 20. Use the Python code provided in section 1.7. to plot confunsion matrices.
#
# 21. Cite every source, including generative AI or websites, if you borrow code lines or text.
#
# 22. **Marks will be deducted for failure to follow the previous instructions.**
#
# 23. Refer to the provided [rubric](https://unsw-my.sharepoint.com/:w:/g/personal/z3368601_ad_unsw_edu_au/EYaMoVWZ20hFoj9R8hL2PIIB4-ACN6c4bf4uCI66gzpEqA?e=tUJZiB).

# %% [markdown]
# ![alt text](https://drive.google.com/uc?export=view&id=105SGqeyo8RgLhSO8mN7ZE5OsG0YiLPKt)

# %% [markdown]
# ## 1.6. Late Submission Penalty
#
# UNSW has a [standard](https://www.unsw.edu.au/arts-design-architecture/student-life/resources-support/protocols-guidelines)  late submission penalty of:
#
#
# *   5% per day,
# *   for all assessments where a penalty applies,
# *   capped at five days (120 hours) from the assessment deadline, after which a student cannot submit an assessment,
# *   and no permitted variation.
#
# Students are expected to manage their time to meet deadlines and to request extensions as early as possible before the deadline.

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 1.7 Python Code Provided

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_confusion_matrix(confusion_matrix, data_set_name, model_name):
    """
    Visualize the confusion matrix with custom labels.

    Args:
    confusion_matrix (array-like): Confusion matrix to be visualized.
    data_set_name (str): Name of the data set. For example, "Training set"
    model_name (str): Name of the model. For example, "Benchmark Logistic Regression"
    """
    # Visualize the confusion matrix
    labels = ['No', 'Yes']
    ax = plt.subplot()
    sns.heatmap(confusion_matrix, annot=True, fmt='.0f', ax=ax, cmap='viridis')

    # Labels, titles, and ticks
    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')
    ax.set_title(f'Confusion Matrix of the {data_set_name} set for the {model_name} model')
    ax.xaxis.set_ticklabels(labels)
    ax.yaxis.set_ticklabels(labels)

    plt.show()

# %%
# Example usage
# Your confusion matrix. This confusion matrix below is just a toy example for illustrative purposes only.
# In your case, this matrix will be generated in a similar way to the notebooks we solved in class.
confusion_matrix = [[50, 10], [5, 35]]  # Replace with your actual confusion matrix
data_set_name = 'Test set'
model_name = 'Random Forest'

plot_confusion_matrix(confusion_matrix, data_set_name, model_name)

# %% [markdown]
# ---

# %% [markdown]
# ## 1.8. Dataset and data dictionary

# %% [markdown]
# 1. Dataset: click  [here](https://drive.google.com/file/d/1q5ryVUjegJMSOMrrEQPu6Ra_xFLoULJ6/view?usp=sharing) to download.

# %% [markdown]
# 2. Data dictionary: click [here](https://drive.google.com/file/d/1nh80X5kBqHf8AxACFWpmqrVq9wiAETAj/view?usp=sharing) to download.

# %% [markdown]
# ---

# %% [markdown]
# ---
# # 2. Questions:

# %% [markdown]
# ## Question 1: Docstring
#
# Create a docstring that includes the following:
#
# 1. Purpose: The top-level aim of our program. (Please limit this to 50 words).
# 2. Author(s)
# 3. Dates
# 4. List of Variables, Constants, and Functions: Describe how each one is used in the program. Ensure that you choose informative variable names and thoroughly document your program (both through docstrings and comments). When required, units should accompany the variables. The list of variables must be written in different sections: General, Question 1, Question 2, ..., Question 9. For the list of variables within each section, list the variables, constants, and functions in alphabetical order.
# 5. Method: The "Method" section in a docstring typically refers to the approach or algorithm used in the program or function. Here, you would describe the sequence of operations or steps your code follows to accomplish its goal.
#
# Structure your docstring into distinct sections, with one section per point listed above. There is not word limit.

# %% [markdown]
# <b> 1. Purpose: The aim of our program:</b>
#
# ################################################################################
#
# Developing predictive models to identify patients at risk of 30-day readmission, enabling timely interventions to improve patient outcomes, reduce readmission rates, and optimize healthcare resource utilization.
#
# ################################################################################

# %% [markdown]
# <b> 2. Author: Zhenyu Zhang</b>
#
# <b> 3. Dates: 02/Jun/2024</b>

# %% [markdown]
# <b> 4. List of variables and constants in alphabetical order:</b>
#
# ################################################################################
#
# ---
#
# <b> General: </b>
# * `pickle_data_path`: Path object containing the path to the pickle file.
# * `hospital`: DataFrame containing the data loaded from the pickle file.
# ---
#
# ---
# <b> Question 1: </b>
#
# * `Not Applicable`
#
# ---
#
# <b> Question 2: </b>
#
# * `X`: DataFrame containing the features (all columns except 'readmission').
# * `y`: Series containing the target variable ('readmission').
# * `y_binary`: List containing the binary target variable (0 for 'no', 1 for 'yes').
# * `X_train`: DataFrame containing the training set features.
# * `X_test`: DataFrame containing the test set features.
# * `y_train`: List containing the training set target variable.
# * `y_test`: List containing the test set target variable.
#
# ---
#
# <b> Question 3: </b>
#
# * `cm_test_logreg`: The confusion matrix for the test set.
# * `cm_train_logreg`: The confusion matrix for the training set.
# * `logreg`: The Logistic Regression model without regularization.
# * `scaler`: The StandardScaler object used to scale the features.
# * `X_test_scaled`: The scaled test data.
# * `X_train_scaled`: The scaled training data.
# * `y_pred_test_logreg`: Predictions made by the Logistic Regression model on the test data.
# * `y_pred_train_logreg`: Predictions made by the Logistic Regression model on the training data.
# * `y_test`: The actual labels for the test data.
# * `y_train`: The actual labels for the training data.
#
# ---
#
# <b> Question 4: Training, and hyper-parameter tuning of the Logistic Regression model.</b>
#
# * `best_pipeline_ws1`: Best model pipeline for weight set 1.
# * `best_pipeline_ws2`: Best model pipeline for weight set 2.
# * `grid_search_ws1`: GridSearchCV object for weight set 1.
# * `grid_search_ws2`: GridSearchCV object for weight set 2.
# * `log_reg`: Logistic Regression model object.
# * `param_grid_ws1`: Hyperparameter grid for weight set 1.
# * `param_grid_ws2`: Hyperparameter grid for weight set 2.
# * `pipeline`: Pipeline object combining scaler and Logistic Regression.
# * `scaler`: StandardScaler object.
# * `y_pred_test_best_ws1`: Predictions on test data for best model with weight set 1.
# * `y_pred_test_best_ws2`: Predictions on test data for best model with weight set 2.
# * `y_pred_train_best_ws1`: Predictions on training data for best model with weight set 1.
# * `y_pred_train_best_ws2`: Predictions on training data for best model with weight set 2.
#
# ---
#
# <b>Question 5: Evaluation of the Logistic Regression: </b>
#
# * `cm_test_best_ws1`: Confusion matrix for the test set (Weight Set 1).
# * `cm_test_best_ws2`: Confusion matrix for the test set (Weight Set 2).
# * `cm_train_best_ws1`: Confusion matrix for the training set (Weight Set 1).
# * `cm_train_best_ws2`: Confusion matrix for the training set (Weight Set 2).
# * `df_gridsearch_combined`: Combined DataFrame of GridSearchCV results for both weight sets.
# * `df_gridsearch_ws1`: DataFrame of GridSearchCV results for weight set 1.
# * `df_gridsearch_ws2`: DataFrame of GridSearchCV results for weight set 2.
# * `pivot_table`: Pivot table for heatmap visualization.
#
#
# ---
#
# <b>Question 6:  </b>
#
# * `best_rf`: Best Random Forest model based on GridSearchCV.
# * `grid_search_rf`: GridSearchCV object for Random Forest.
# * `param_grid_rf`: Hyperparameter grid for Random Forest tuning.
# * `rf`: Random Forest Classifier model instance.
# * `X_train_scaled`: Scaled training feature set.
# * `y_train`: Training target variable.
#
# ---
#
# <b> Question 7: </b>
#
# * `cm_test_rf`: Confusion matrix for the test set predictions by the Random Forest model.
# * `cm_train_rf`: Confusion matrix for the training set predictions by the Random Forest model.
# * `y_pred_test_rf`: Predictions of the Random Forest model on the test set.
# * `y_pred_train_rf`: Predictions of the Random Forest model on the training set.
#
# ---
#
# <b> Question 8: </b>
#
# * `cost_per_intervention`: Cost for each intervention by the specialized unit, set to 3000 dollars.
# * `cost_per_readmission`: Cost for each readmission, set to 15000 dollars.
# * `cost_rf`: Total cost for interventions and readmissions for the Random Forest model.
# * `cost_ws1`: Total cost for interventions and readmissions for the Logistic Regression model with Elastic Net (Weight Set 1).
# * `cost_ws2`: Total cost for interventions and readmissions for the Logistic Regression model with Elastic Net (Weight Set 2).
# * `data`: Dictionary containing model names, readmissions, interventions, and costs for each model.
# * `df_cost_comparison`: DataFrame comparing the costs of interventions and readmissions across different models.
# * `interventions_rf`: Number of interventions for the Random Forest model.
# * `interventions_ws1`: Number of interventions for the Logistic Regression model with Elastic Net (Weight Set 1).
# * `interventions_ws2`: Number of interventions for the Logistic Regression model with Elastic Net (Weight Set 2).
# * `readmissions_rf`: Number of readmissions for the Random Forest model.
# * `readmissions_ws1`: Number of readmissions for the Logistic Regression model with Elastic Net (Weight Set 1).
# * `readmissions_ws2`: Number of readmissions for the Logistic Regression model with Elastic Net (Weight Set 2).
#
# ---
# ################################################################################

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## Question 2: Read and check the pickle file provided. Prepare the data so it can be used by the algorithms that you are going to create.  Divide the data into 80% for training and 20% for testing using `train_test_split` and a random seed of 30. Set the other hyperparameters of `train_test_split` as you deem appropriate.
# ---

# %% [markdown]
# bold text<b> Rationale: What are you doing to solve this question? - 100 word count limit:</b>
#
#
# ################################################################################
#
# Firstly, mounting Google Drive, setting the project path and download the 'hospital_data_project01_assignment.pickle' in the project path. Secondly, loading and inspecting the dataset from a pickle file to understand the structure. Then, separating the features (X) and the target variable (y), converting the target to a binary format. Finally, splitting the data into training (80%) and testing (20%) sets using `train_test_split` with random seed of `30`, and use `stratify=y` to ensure stratification, maintaining class proportions. This split allows for training models on one subset and evaluating their performance on an unseen subset, ensuring the results are reliable and the model generalizes well to new data.
#
# ################################################################################

# %%
# Import necessary libraries
import sys
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier

# %%
# Mount Google Drive
if 'google.colab' in str(get_ipython()):
    from google.colab import drive # import drive from Gogle colab
    root = '/content/drive'     # default location for the drive
    # print(root)                 # print content of ROOT (Optional)
    drive.mount(root)
else:
    print('Not running on CoLab')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path

if 'google.colab' in str(get_ipython()):
    # EDIT THE PROJECT PATH IF DIFFERENT WITH YOUR ONE
    project_path = Path(root) / 'MyDrive' / 'Colab Notebooks' / 'HDAT9500' / 'project'
    # OPTIONAL - set working directory according to your google drive project path
    # import os
    # Change directory to the location defined in project_path
    # os.chdir(project_path)
else:
    project_path = Path()

# %%
# Read the pickle file
pickle_data_path = Path(project_path) /'hospital_data_project01_assignment.pickle'
hospital = pd.read_pickle(pickle_data_path) # Data loading and initial inspection verified (sanity check `hospital.head(n=20)` and `hospital.info()` performed)

# %%
# Dividing my dataset in X and y (outcome)
X = hospital.drop(axis=1, columns=['readmission'])
y = hospital['readmission']

# Create y_binary (Sanity Checks done)
y_binary = [0 if x=='no' else 1 for x in y]

# %%
from sklearn.model_selection import train_test_split
# Split X and y into 80% train and 20% test data (roughly), set random state for reproducibility and stratify responses
X_train, X_test, y_train, y_test = train_test_split(X, y_binary, test_size=0.2, random_state=30, stratify=y) # `stratify = y` to preserve the ratio between readmission=NO to readmission=YES.

# %%
# Display the number of samples in the training and test sets
print("Number of samples in the training set:", len(X_train))
print("Number of samples in the test set:", len(X_test))
print("Number of 'yes' in y_train:", sum(y_train))
print("Number of 'no' in y_train:", len(y_train) - sum(y_train))
print("Number of 'yes' in y_test:", sum(y_test))
print("Number of 'no' in y_test:", len(y_test) - sum(y_test))
# Out:
# Number of samples in the training set: 55413
# Number of samples in the test set: 13854
# Number of 'yes' in y_train: 9535
# Number of 'no' in y_train: 45878
# Number of 'yes' in y_test: 2384
# Number of 'no' in y_test: 11470

# %% [markdown]
# Number of samples in the training set: 55413
# Number of samples in the test set: 13854
# Number of 'yes' in y_train: 9535
# Number of 'no' in y_train: 45878
# Number of 'yes' in y_test: 2384
# Number of 'no' in y_test: 11470

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## Question 3: Benchmark - Create, train and evaluate a benchmark model. In this case, a Logistic Regression with no reguralization.  Use the `plot_confusion_matrix()` function provided above to display the evaluation results.
# ---

# %% [markdown]
# <b> Rationale: What are you doing to solve this question?- 100 word count limit:</b>
#
#
# ################################################################################
#
# For establishing a baseline performance, use a Logistic Regression model without regularization as a benchmark model. After training the model on the training data and evaluate the model on the test data, analysing its performance using classification reports and confusion matrices. This simple model helps to understand the data and provides a reference point for more complex models.
#
#
#
#
# ################################################################################

# %%
# Limit for Python code: 20 lines. No limit for comments (the definition of comments is anything like this comment, that is, precedeed by #)

# Scaling the features
scaler = StandardScaler() # Initialize the StandardScaler
scaler.fit(X_train)  # Fit scaler on the training data only avoid Data leakage

X_train_scaled = scaler.transform(X_train)  # Scale training data
X_test_scaled = scaler.transform(X_test)    # Scale test data

# Train the Logistic Regression model without regularization on scaled data
logreg = LogisticRegression(penalty=None, random_state=30) # The penalty parameter set to `None` to indicate no regularization
logreg.fit(X_train_scaled, y_train)

# Predict on the training and test data
y_pred_train_logreg = logreg.predict(X_train_scaled)  # training
y_pred_test_logreg = logreg.predict(X_test_scaled)  # test

# Evaluate the model
print("Classification Report for Logistic Regression (no regularization) on Test Data:")
print(classification_report(y_test, y_pred_test_logreg))

# Confusion Matrix
cm_train_logreg = confusion_matrix(y_true=y_train, y_pred=y_pred_train_logreg) # for the training set
cm_test_logreg = confusion_matrix(y_true=y_test, y_pred=y_pred_test_logreg) # for the test set

# Plot the confusion matrices using the provided function
plot_confusion_matrix(cm_train_logreg, 'Training', 'Logistic Regression (no regularization)')
plot_confusion_matrix(cm_test_logreg, 'Test', 'Logistic Regression (no regularization)')
# Out:
# Classification Report for Logistic Regression (no regularization) on Test Data:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     11470
#            1       0.94      0.93      0.93      2384
#
#     accuracy                           0.98     13854
#    macro avg       0.96      0.96      0.96     13854
# weighted avg       0.98      0.98      0.98     13854

# %% [markdown]
# Classification Report for Logistic Regression (no regularization) on Test Data:
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     11470
#            1       0.94      0.93      0.93      2384
#     accuracy                           0.98     13854
#     macro avg      0.96      0.96      0.96     13854
#     weighted avg   0.98      0.98      0.98     13854

# %% [markdown]
# ---

# %% [markdown]
# Please Note: Following codes are just test integrating regularization into the Question 3, not for answer the Question 3

# %%
# Train the Logistic Regression model with L1 regularization on scaled data
logreg_l1 = LogisticRegression(C=0.01, penalty='l1', solver='liblinear', random_state=30)
logreg_l1.fit(X_train_scaled, y_train)

# Predict on the training and test data for L1 regularization
y_pred_train_logreg_l1 = logreg_l1.predict(X_train_scaled)
y_pred_test_logreg_l1 = logreg_l1.predict(X_test_scaled)

# Evaluate the L1 model
print("Classification Report for Logistic Regression (L1 regularization) on Test Data:")
print(classification_report(y_test, y_pred_test_logreg_l1))

# Compute and plot the confusion matrices for L1 regularization
cm_train_logreg_l1 = confusion_matrix(y_true=y_train, y_pred=y_pred_train_logreg_l1)
cm_test_logreg_l1 = confusion_matrix(y_true=y_test, y_pred=y_pred_test_logreg_l1)

plot_confusion_matrix(cm_train_logreg_l1, 'Training', 'Logistic Regression (L1 regularization)')
plot_confusion_matrix(cm_test_logreg_l1, 'Test', 'Logistic Regression (L1 regularization)')

# Train the Logistic Regression model with L2 regularization on scaled data
logreg_l2 = LogisticRegression(C=0.01, penalty='l2', solver='liblinear', random_state=30)
logreg_l2.fit(X_train_scaled, y_train)

# Predict on the training and test data for L2 regularization
y_pred_train_logreg_l2 = logreg_l2.predict(X_train_scaled)
y_pred_test_logreg_l2 = logreg_l2.predict(X_test_scaled)

# Evaluate the L2 model
print("Classification Report for Logistic Regression (L2 regularization) on Test Data:")
print(classification_report(y_test, y_pred_test_logreg_l2))

# Compute and plot the confusion matrices for L2 regularization
cm_train_logreg_l2 = confusion_matrix(y_true=y_train, y_pred=y_pred_train_logreg_l2)
cm_test_logreg_l2 = confusion_matrix(y_true=y_test, y_pred=y_pred_test_logreg_l2)

plot_confusion_matrix(cm_train_logreg_l2, 'Training', 'Logistic Regression (L2 regularization)')
plot_confusion_matrix(cm_test_logreg_l2, 'Test', 'Logistic Regression (L2 regularization)')
# Out:
# Classification Report for Logistic Regression (L1 regularization) on Test Data:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     11470
#            1       0.93      0.92      0.93      2384
#
#     accuracy                           0.97     13854
#    macro avg       0.96      0.95      0.96     13854
# weighted avg       0.97      0.97      0.97     13854
# Classification Report for Logistic Regression (L2 regularization) on Test Data:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99     11470
#            1       0.94      0.93      0.93      2384
#
#     accuracy                           0.98     13854
#    macro avg       0.96      0.96      0.96     13854
# weighted avg       0.98      0.98      0.98     13854

# %% [markdown]
# ---
# ## Question 4: Model 1 - Train and tune the hyperparameters of a Logistic Regression model with Elastic Net reguralization.
#
# Hyper-parameters:
#
# - `C` values: 10, 100.
# - `class_weight`: only two pairs. Choose one of these two combinations and explain why you think the weights are important.
#
#     * A weight of (80% for class 1, 20% for class 0) and (70% for class 1, 30% for class 0)
#     * A weight of (80% for class 0, 20% for class 1) and (70% for class 0, 30% for class 1).
# - 3-fold cross-validation for the grid search.
# - `f1` as the score to choose the best model in the grid search.
# - `n_jobs`=-1.
# - do not include the heatmaps in the final submission.
# - do not change these hyper-parameters.
# - keep the remaining set of hyperparameters in the default state.
# - if you do not know how to incorporate some of the hyperparameters, please proceed with those you know how to incorporate. This will be reflected in your mark, but you will still receive some credit.
# ---

# %% [markdown]
# <b> Rationale: What are you doing to solve this question?-100 word count limit:</b>
#
#
# ################################################################################
#
# The data has been split into training and test sets, and the features will be standardized using `StandardScaler`.
# To address this question, training a Logistic Regression model with Elastic Net regularization and tune its hyperparameters (regularization strength `C`, `class weights`, and `l1_ratio`) using GridSearchCV. Elastic Net combines both L1(Lasso) and L2(Ridge) regularization, which helps in both feature selection and handling multicollinearity.
# Use GridSearchCV to find the best combination of `C` and `class_weight` with 3-fold cross-validation and f1 as the scoring metric to balance precision and recall.
# The final model is evaluated using the confusion matrix and classification report metrics.
#
# ################################################################################

# %%
# Define the scaler and model
scaler = StandardScaler()
log_reg = LogisticRegression(solver='saga', max_iter=500)  # Use saga for ‘elasticnet’ regularization; Increase max_iter (default 100) to convergence

# Create the pipeline
pipeline = Pipeline([
    ('scaler', scaler),
    ('log_reg', log_reg)
])

# Define the hyperparameter grid for weight set 1
param_grid_ws1 = {
    'log_reg__C': [10, 100],
    'log_reg__class_weight': [{1: 0.8, 0: 0.2}, {1: 0.7, 0: 0.3}],
    'log_reg__penalty': ['elasticnet'],
    'log_reg__l1_ratio': [0.1, 0.5, 0.9]  # Testing different l1_ratio values
}

# Create the GridSearchCV object for weight set 1
grid_search_ws1 = GridSearchCV(pipeline, param_grid_ws1, cv=3, scoring='f1', n_jobs=-1) # `cv=3`: Number of cross-validation folds. `n_jobs=-`: Use all available processors for parallel computation.

# Fit the grid search to the training data for weight set 1
grid_search_ws1.fit(X_train_scaled, y_train)

# Print the best parameters and score for weight set 1
print(f"Best parameters for weight set 1: {grid_search_ws1.best_params_}")
print(f"Best cross-validation score (f1) for weight set 1: {grid_search_ws1.best_score_:.4f}")

# Train the best model on the full training data for weight set 1
best_pipeline_ws1 = grid_search_ws1.best_estimator_
best_pipeline_ws1.fit(X_train_scaled, y_train)

# Predict on the test data for weight set 1
y_pred_train_best_ws1 = best_pipeline_ws1.predict(X_train_scaled)
y_pred_test_best_ws1 = best_pipeline_ws1.predict(X_test_scaled)
# Out:
# Best parameters for weight set 1: {'log_reg__C': 100, 'log_reg__class_weight': {1: 0.7, 0: 0.3}, 'log_reg__l1_ratio': 0.1, 'log_reg__penalty': 'elasticnet'}
# Best cross-validation score (f1) for weight set 1: 0.9333

# %% [markdown]
# Best parameters for weight set 1: {'log_reg__C': 100, 'log_reg__class_weight': {1: 0.7, 0: 0.3}, 'log_reg__l1_ratio': 0.1, 'log_reg__penalty': 'elasticnet'}
# Best cross-validation score (f1) for weight set 1: 0.9333

# %% [markdown]
# <b>Comments for Question 4 Results</b>
#
# The Logistic Regression model with Elastic Net regularization was tuned using two different weight sets. For weight set 1, the best parameters found were C=10, class_weight={1: 0.7, 0: 0.3}, and l1_ratio=0.1 (10% L1 and 90% L2 regularization), resulting in a cross-validation F1 score of 0.9333.
#
# For weight set 2, the best parameters were C=100, class_weight={0: 0.7, 1: 0.3}, and l1_ratio=0.5 (balanced L1 and L2 regularization), with a cross-validation F1 score of 0.9136.
#
#
# <b>Importance of Weights</b>
#
# The weights are important because they address class imbalance by assigning different costs to misclassifications of each class. For example, if predicting readmission (class 1) is critical in healthcare as failing to do so can lead to adverse patient outcomes and higher costs. By increasing the weight for class 1, the model focuses more on correctly predicting readmissions. Conversely, for some scenarios, the weight set might prioritize non-readmissions (class 0) to avoid unnecessary interventions. Therefore, the weight should be adjust based on application environment.
#
# - **Weight Set 1**: The higher weight for class 1 (70% for class 1, 30% for class 0) ensures that the model pays more attention to the minority class, leading to better recall.
#
# - **Weight Set 2**: The higher weight for class 0 (70% for class 0, 30% for class 1) might be less effective in capturing the minority class, as reflected in the slightly lower F1 score.

# %% [markdown]
# The Convergence Warning: The max_iter was reached which means the coef_ did not converge is a warning issued by scikit-learn when the optimization algorithm used to train the logistic regression model fails to converge to a solution within the specified number of iterations (max_iter).
#
# Reasons for Non-Convergence:
# - Insufficient Iterations: The specified max_iter (maximum number of iterations) is too low, and the algorithm needs more iterations to converge.
# - Poor Initialization: The initial guess for the coefficients is far from the optimal solution, requiring more iterations to converge.
# - Complex Model: The model may be too complex or the data too noisy, making it hard for the algorithm to find a stable set of coefficients.
# - Regularization Parameter: In Elastic Net regularization, the balance between L1 and L2 penalties (controlled by l1_ratio) and the regularization strength (C) can impact convergence. Too high or too low values might make it hard for the model to converge.
#
# max_iter: Maximum number of iterations taken for the solvers to converge. [int, default=100]
#
# Increase max_iter to 500 via adding `max_iter=500` in LogisticRegression(), if not test different l1_ratio values (default l1_ratio is 0.5) for Elastic Net regularization, `max_iter=200` is enough to converge.

# %% [markdown]
# Please Note: The following code chunk is just a test for the other weight combination for data exploration, not include in the answer of question 3. It can be skiped.

# %%
# Define the hyperparameter grid for weight set 2
param_grid_ws2 = {
    'log_reg__C': [10, 100],
    'log_reg__class_weight': [{0: 0.8, 1: 0.2}, {0: 0.7, 1: 0.3}],
    'log_reg__penalty': ['elasticnet'],
    'log_reg__l1_ratio': [0.1, 0.5, 0.9]  # Adding default l1_ratio for Elastic Net regularization
}

# Create the GridSearchCV object
grid_search_ws2 = GridSearchCV(pipeline, param_grid_ws2, cv=3, scoring='f1', n_jobs=-1)

# Fit the grid search to the training data
grid_search_ws2.fit(X_train_scaled, y_train)

# Print the best parameters and score for weight set 2
print(f"Best parameters for weight set 2: {grid_search_ws2.best_params_}")
print(f"Best cross-validation score (f1) for weight set 2: {grid_search_ws2.best_score_:.4f}")

# Train the best model on the full training data
best_pipeline_ws2 = grid_search_ws2.best_estimator_
best_pipeline_ws2.fit(X_train_scaled, y_train)

# Predict on the test data
y_pred_train_best_ws2 = best_pipeline_ws2.predict(X_train_scaled)
y_pred_test_best_ws2 = best_pipeline_ws2.predict(X_test_scaled)
# Out:
# Best parameters for weight set 2: {'log_reg__C': 100, 'log_reg__class_weight': {0: 0.7, 1: 0.3}, 'log_reg__l1_ratio': 0.5, 'log_reg__penalty': 'elasticnet'}
# Best cross-validation score (f1) for weight set 2: 0.9136

# %% [markdown]
# Best parameters for weight set 2: {'log_reg__C': 100, 'log_reg__class_weight': {0: 0.7, 1: 0.3}, 'log_reg__l1_ratio': 0.5, 'log_reg__penalty': 'elasticnet'}
# Best cross-validation score (f1) for weight set 2: 0.9136

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## Question 5: Evaluate Model 1 - Logistic Regression with Elastic Net reguralization. Use the `plot_confusion_matrix(confusion_matrix`) function provided above to display the results.
# ---

# %% [markdown]
# <b> Rationale: Why are we evaluating the model? What are you doing to solve this question?- 120 word count limit:</b>
#
#
# ################################################################################
#
# To evaluate the performance of the Logistic Regression model with Elastic Net regularization, confusion matrix and classification report are used to help understand how well our model predicts both classes (readmission 'Yes' and 'No') on the test set. By examining metrics such as precision, recall, and F1-score, we can assess the model's ability to balance false positives and false negatives. Additionally, visualization of the confusion matrix providing a clear picture of the model's performance.
#
#
# ################################################################################

# %%
# Limit for Python code: 25 lines. No limit for comments.
# Evaluate the model for weight set 1
print("Classification Report for Logistic Regression with Elastic Net Regularization on Test Data (Weight Set 1):")
print(classification_report(y_test, y_pred_test_best_ws1))

# Confusion Matrix for the training set (Weight Set 1)
cm_train_best_ws1 = confusion_matrix(y_true=y_train, y_pred=y_pred_train_best_ws1)
# Confusion Matrix for the test set (Weight Set 1)
cm_test_best_ws1 = confusion_matrix(y_true=y_test, y_pred=y_pred_test_best_ws1)

# Plot the confusion matrices using the provided function
plot_confusion_matrix(cm_train_best_ws1, 'Training', 'Logistic Regression with Elastic Net Regularization (Weight Set 1)')
plot_confusion_matrix(cm_test_best_ws1, 'Test', 'Logistic Regression with Elastic Net Regularization (Weight Set 1)')
# Out:
# Classification Report for Logistic Regression with Elastic Net Regularization on Test Data (Weight Set 1):
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98     11470
#            1       0.90      0.96      0.93      2384
#
#     accuracy                           0.98     13854
#    macro avg       0.95      0.97      0.96     13854
# weighted avg       0.98      0.98      0.98     13854

# %% [markdown]
# Classification Report for Logistic Regression with Elastic Net Regularization on Test Data (Weight Set 1):
#
#               precision    recall  f1-score   support
#            0       0.99      0.98      0.98     11470
#            1       0.90      0.96      0.93      2384
#     accuracy                           0.98     13854
#     macro avg      0.95      0.97      0.96     13854
#     weighted avg   0.98      0.98      0.98     13854

# %%
# Evaluate the model for weight set 2
print("Classification Report for Logistic Regression with Elastic Net Regularization on Test Data (Weight Set 2):")
print(classification_report(y_test, y_pred_test_best_ws2))

# Confusion Matrix for the training set (Weight Set 2)
cm_train_best_ws2 = confusion_matrix(y_true=y_train, y_pred=y_pred_train_best_ws2)
# Confusion Matrix for the test set (Weight Set 2)
cm_test_best_ws2 = confusion_matrix(y_true=y_test, y_pred=y_pred_test_best_ws2)

# Plot the confusion matrices using the provided function
plot_confusion_matrix(cm_train_best_ws2, 'Training', 'Logistic Regression with Elastic Net Regularization (Weight Set 2)')
plot_confusion_matrix(cm_test_best_ws2, 'Test', 'Logistic Regression with Elastic Net Regularization (Weight Set 2)')
# Out:
# Classification Report for Logistic Regression with Elastic Net Regularization on Test Data (Weight Set 2):
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     11470
#            1       0.95      0.88      0.92      2384
#
#     accuracy                           0.97     13854
#    macro avg       0.96      0.94      0.95     13854
# weighted avg       0.97      0.97      0.97     13854

# %% [markdown]
# Classification Report for Logistic Regression with Elastic Net Regularization on Test Data (Weight Set 2):
#
#               precision    recall  f1-score   support
#            0       0.98      0.99      0.98     11470
#            1       0.95      0.88      0.92      2384
#
#     accuracy                           0.97     13854
#     macro avg      0.96      0.94      0.95     13854
#     weighted avg   0.97      0.97      0.97     13854

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore') # Prevent warnings

# Creating DataFrame with GridSearchCV results from both weight sets
df_gridsearch_ws1 = pd.DataFrame(grid_search_ws1.cv_results_)
df_gridsearch_ws2 = pd.DataFrame(grid_search_ws2.cv_results_)

# Add a column to distinguish the weight sets
df_gridsearch_ws1['weight_set'] = 'Weight Set 1'
df_gridsearch_ws2['weight_set'] = 'Weight Set 2'

# Concatenate both DataFrames
df_gridsearch_combined = pd.concat([df_gridsearch_ws1, df_gridsearch_ws2])

# Extract relevant columns
df_gridsearch_combined = df_gridsearch_combined[['param_log_reg__C', 'param_log_reg__class_weight', 'mean_test_score', 'weight_set']]

# Convert the 'class_weight' dictionary to a string for better visualization
df_gridsearch_combined['param_log_reg__class_weight'] = df_gridsearch_combined['param_log_reg__class_weight'].apply(lambda x: str(x))

# Pivot the DataFrame to have 'C' as rows and 'class_weight' and 'weight_set' as columns
pivot_table = df_gridsearch_combined.pivot_table(index='param_log_reg__C', columns=['weight_set', 'param_log_reg__class_weight'], values='mean_test_score')

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, annot=True, fmt='.5g', cmap='viridis')
plt.title("Mean Cross-Validation F1-Score as a Function of 'C' and 'class_weight' for Both Weight Sets")
plt.xlabel("class_weight and weight_set")
plt.ylabel("C")
plt.show()

# %% [markdown]
# <b>Comments for Question 5 Results</b>
#
# Class weights are crucial because they address class imbalance by assigning a higher penalty to misclassifications of the minority class.
# - **Weight Set 1**: (80% for class 1, 20% for class 0) and (70% for class 1, 30% for class 0). This set prioritizes the identification of at-risk patients, which is more sensitive to identifying those at risk of readmission. It reducing false negatives at the cost of potentially increasing false positives,  leading to potentially unnecessary interventions and increased costs..
# - **Weight Set 2**: (80% for class 0, 20% for class 1) and (70% for class 0, 30% for class 1). This set is more sensitive to correctly identifying those not at risk of readmission. Higher precision for the majority class, meaning fewer false positives. This can reduce unnecessary interventions and associated costs. However, it increases the risk of missing more at-risk patients leading to worse patient outcomes.
#
# <b> Analysis and Comparison</b>
# - **Weight Set 1**:
#    - **Recall** is higher for class 1 (Yes) in Weight Set 1. This means that this model is better at identifying patients who will be readmitted within 30 days.
#    - **Precision** is lower for class 1 (Yes) compared to Weight Set 2. This indicates a higher rate of false positives, meaning more patients are identified as high risk when they are not.
#    - **F1-score** for class 1 is slightly higher, indicating a better balance between precision and recall.
#
# - **Weight Set 2**:
#    - **Precision** is higher for class 1 (Yes). This means that when the model predicts a patient will be readmitted, it is more likely to be correct.
#    - **Recall** is lower for class 1 (Yes), indicating that the model misses more actual readmissions compared to Weight Set 1.
#    - **F1-score** for class 1 is slightly lower, showing a slight compromise in balancing precision and recall.
#
# <b> Heatmap Interpretation</b>
#
# - The heatmap of mean cross-validation F1-scores for both weight sets shows that Weight Set 1 with `C` value of 10, performs the best overall, with an F1-score of 0.93332.
# - Weight Set 2 generally performs lower in terms of F1-score compared to Weight Set 1, which suggests that the model benefits more from prioritizing recall (catching more readmissions) over precision (fewer false positives).

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## Question 6: Model 2 - Train and tune the hyperparameters of the of the Random Forest model.
#
# Fixed hyper-parameters (do not change the values of these hyper-parameters):
#
# - `n_estimators`: 125, 150
# - `class_weight`: Only two pairs. Choose one of these two combinations (either combination 1 or combination 2) and explain why.
# 1. A weight of (80% for class 1, 20% for class 0) and (70% for class 1, 30% for class 0)
# 2.  A weight of (80% for class 0, 20% for class 1) and (70% for class 0, 30% for class 1).
# - 3-fold cross-validation for the grid search.
# - Select the score to choose the best model in the grid search.
# - `n_jobs`=-1
# - `max_features`: 20, 30,
# - `min_samples_split`: 20
# -  do not include the heatmaps in the final submission
# -  do not change these hyper-parameters.
# -  keep the remaining set of hyperparameters in the default state.
# -  if you do not know how to incorporate some of the hyperparameters, please proceed with those you know how to incorporate. This will be reflected in your mark, but you will still receive some credit.
# ---

# %% [markdown]
# <b> Rationale: What are you doing to solve this question?-150 word count limit:</b>
#
#
# ################################################################################
#
# Developing a Random Forest model and use GridSearchCV to tune its hyperparameters. Considering both weight sets for class weights and test different values for the number of estimators (`n_estimators`) and maximum features (`max_features`). The goal is to select the best parameters for the model with the best performance using 3-fold cross-validation for grid search.
#
# By tuning hyperparameters, improving the model's ability to predict hospital readmissions accurately, balancing the trade-off between false positives and false negatives. The final model was evaluated based on its F1 score, which provides a balanced measure of precision and recall.
#
# Although the question request to choose one of these two weight combinations, by testing both combinations (Combination 1 emphasizes sensitivity (recall); Combination 2 emphasizes precision to minimize false positives), we can balancing the trade-off between precision and recall, ensuring the selected model provides the best overall performance for predicting hospital readmissions.
#
# ################################################################################

# %%
# Limit for Python code: 15 lines. No limit for comments.
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# Define the Random Forest model
rf = RandomForestClassifier(random_state=30, min_samples_split=20)

# Define the hyperparameter grid (I put combination 1 and 2 together)
param_grid_rf = {
    'n_estimators': [125, 150],
    'max_features': [20, 30],
    'class_weight': [
        {1: 0.8, 0: 0.2},
        {1: 0.7, 0: 0.3},
        {0: 0.8, 1: 0.2},
        {0: 0.7, 1: 0.3}
    ]
}

# Create the GridSearchCV object
grid_search_rf = GridSearchCV(rf, param_grid_rf, cv=3, scoring='f1', n_jobs=-1)

# Fit the grid search to the training data
grid_search_rf.fit(X_train_scaled, y_train)

# Print the best parameters and score
print(f"Best parameters for Random Forest: {grid_search_rf.best_params_}")
print(f"Best cross-validation score (f1) for Random Forest: {grid_search_rf.best_score_:.4f}")

# Train the best model on the full training data
best_rf = grid_search_rf.best_estimator_
best_rf.fit(X_train_scaled, y_train)
# Out:
# Best parameters for Random Forest: {'class_weight': {1: 0.7, 0: 0.3}, 'max_features': 20, 'n_estimators': 150}
# Best cross-validation score (f1) for Random Forest: 0.9454
# RandomForestClassifier(class_weight={0: 0.3, 1: 0.7}, max_features=20,
#                        min_samples_split=20, n_estimators=150, random_state=30)

# %% [markdown]
# ---

# %% [markdown]
# Best parameters for Random Forest: {'class_weight': {1: 0.7, 0: 0.3}, 'max_features': 20, 'n_estimators': 150}
# Best cross-validation score (f1) for Random Forest: 0.9454

# %% [markdown]
# <b>Comments for Question 6 Results</b>
#
# The Random Forest model was trained and tuned using GridSearchCV. The best parameters found were `n_estimators=150`, `max_features=20`, and `class_weight={1: 0.7, 0: 0.3}`. This combination achieved a cross-validation F1 score of 0.9454. The choice of class weights {1: 0.7, 0: 0.3} emphasizes identifying readmission cases more accurately, balancing sensitivity and specificity, which is crucial for predicting hospital readmissions and allowing for timely interventions.
#
# Including both weight set combinations in the hyperparameter grid allowed us to thoroughly evaluate the model's performance and select the best configuration for optimal readmission prediction.

# %% [markdown]
# ---
# ## Question 7: Evaluate Model 2 - Random Forest. Use the `plot_confusion_matrix(confusion_matrix)` function provided above to display the results.
# ---

# %% [markdown]
# <b> Rationale: Why are we evaluating the model? What are you doing to solve this question?- 120 word count limit:</b>
#
# ################################################################################
#
# To assess the effectiveness of the Random Forest model in predicting patient readmissions, The evaluation is performed via confusion matrix and classification report.
#
# By visualizing the confusion matrix, the distribution of true positives, true negatives, false positives, and false negatives can sesily accessed. Classification report metrics provide insights into the model's precision, recall, and F1-score, indicating how well it identifies both positive (readmission) and negative (no readmission) cases.
#
#
# ################################################################################

# %%
# Limit for Python code: 15 lines. No limit for comments.
# Predict on the training and test data
y_pred_train_rf = best_rf.predict(X_train_scaled)
y_pred_test_rf = best_rf.predict(X_test_scaled)

# Evaluate the model
print("Classification Report for Random Forest on Test Data:")
print(classification_report(y_test, y_pred_test_rf))

# Confusion Matrix for the training set
cm_train_rf = confusion_matrix(y_true=y_train, y_pred=y_pred_train_rf)
# Confusion Matrix for the test set
cm_test_rf = confusion_matrix(y_true=y_test, y_pred=y_pred_test_rf)

# Plot the confusion matrices using the provided function
plot_confusion_matrix(cm_train_rf, 'Training', 'Random Forest')
plot_confusion_matrix(cm_test_rf, 'Test', 'Random Forest')
# Out:
# Classification Report for Random Forest on Test Data:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99     11470
#            1       0.93      0.97      0.95      2384
#
#     accuracy                           0.98     13854
#    macro avg       0.96      0.98      0.97     13854
# weighted avg       0.98      0.98      0.98     13854

# %% [markdown]
# ---

# %% [markdown]
# Classification Report for Random Forest on Test Data:
#
#               precision    recall  f1-score   support
#            0       0.99      0.98      0.99     11470
#            1       0.93      0.97      0.95      2384
#
#     accuracy                           0.98     13854
#     macro avg      0.96      0.98      0.97     13854
#     weighted avg   0.98      0.98      0.98     13854

# %% [markdown]
# The model 2 demonstrates high accuracy, precision, and recall, particularly for class 0 (no readmission). However, it also shows strong performance for class 1 (readmission), making it a robust choice for predicting patient readmissions.

# %% [markdown]
# ---
# ## Question 8: Based on the research questions and instructions, determine which model, if any, you would choose. Justify the strengths, limitations, pros, and cons of your model. Explain whether or not you would deploy this model.
# ---

# %% [markdown]
# <b> Rationale: 350 word count limit </b>
#
# ################################################################################
#
# After evaluation, the Random Forest model with class weights set to {1: 0.7, 0: 0.3} is the best model for this task.
#
# - **Precision and Recall:** The Random Forest model achieved high precision (0.93) and recall (0.97) for the positive class (readmitted patients), which indicates that it performs well in identifying the patients who are at risk of readmission while maintaining a low rate of false positives.
# - **F1-Score:** The F1-score for the Random Forest model is 0.95, which is higher than the F1-scores achieved by the Logistic Regression models with Elastic Net regularization (0.93 for Weight Set 1 and 0.92 for Weight Set 2).
# - **Overall Accuracy:** The Random Forest model achieved an overall accuracy of 0.98, which is slightly higher than the Logistic Regression models' accuracies.
# - **Balanced Class Weights:** The Random Forest model effectively handled the class imbalance, ensuring that the model did not overly favor the majority class and was effective in identifying readmitted patients.
# - **Robustness:** Random Forests are known for their robustness and ability to handle various types of data. They are less prone to overfitting compared to single models like Logistic Regression.
# - **Cost:** Random Forest has the lowest total cost ($8,502,000) due to its lowest number of readmissions and a reasonable number of interventions.
#
# ################################################################################

# %%
# You may need to Limit for Python code: 20 lines.
# Compare the models based on evaluation metrics (previous codes and results, just show them all here again)
# Logistic Regression with Elastic Net Regularization (Weight Set 1)
print("Classification Report for Logistic Regression (Elastic Net, Weight Set 1) on Test Data:")
print(classification_report(y_test, y_pred_test_best))

# Logistic Regression with Elastic Net Regularization (Weight Set 2)
print("Classification Report for Logistic Regression (Elastic Net, Weight Set 2) on Test Data:")
print(classification_report(y_test, y_pred_test_best_ws2))

# Random Forest
print("Classification Report for Random Forest on Test Data:")
print(classification_report(y_test, y_pred_test_rf))
# Out:
# Classification Report for Logistic Regression (Elastic Net, Weight Set 1) on Test Data:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98     11470
#            1       0.90      0.96      0.93      2384
#
#     accuracy                           0.98     13854
#    macro avg       0.95      0.97      0.96     13854
# weighted avg       0.98      0.98      0.98     13854
#
# Classification Report for Logistic Regression (Elastic Net, Weight Set 2) on Test Data:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     11470
#            1       0.95      0.88      0.92      2384
#
#     accuracy                           0.97     13854
#    macro avg       0.96      0.94      0.95     13854
# weighted avg       0.97      0.97      0.97     13854
#
# Classification Report for Random Forest on Test Data:
#               precision    recall  f1-score   support
#
# ...

# %% [markdown]
# Total Cost = (TP + FP) * Cost of Intervention + FN * Cost of Readmission
#
# - Cost of Intervention: An intervention by the specialized unit costs, on average, $3,000. This amount includes the cost of the average number of visits per patient, which is three visits.
#
# - Cost of Readmission: The average cost of a day in the hospital is 5,000 dollars; readmitted patients tend to stay for an average of 3 days. Therefore, each readmission costs approximately $15,000.

# %% [markdown]
# ---

# %%
# Define the costs
cost_per_readmission = 15000  # Cost for each readmission
cost_per_intervention = 3000  # Cost for each intervention

# Calculate costs for Logistic Regression with Elastic Net (Weight Set 1)
interventions_ws1 = cm_test_best_ws1[1, 1] + cm_test_best_ws1[0, 1]
readmissions_ws1 = cm_test_best_ws1[1, 0]

cost_ws1 = interventions_ws1 * cost_per_intervention + readmissions_ws1 * cost_per_readmission

# Calculate costs for Logistic Regression with Elastic Net (Weight Set 2)
interventions_ws2 = cm_test_best_ws2[1, 1] + cm_test_best_ws2[0, 1]
readmissions_ws2 = cm_test_best_ws2[1, 0]

cost_ws2 = interventions_ws2 * cost_per_intervention + readmissions_ws2 * cost_per_readmission

# Calculate costs for Random Forest
interventions_rf = cm_test_rf[1, 1] + cm_test_rf[0, 1]
readmissions_rf = cm_test_rf[1, 0]

cost_rf = interventions_rf * cost_per_intervention + readmissions_rf * cost_per_readmission

# Compile the results into a DataFrame for comparison
data = {
    'Model': ['Logistic Regression (WS1)', 'Logistic Regression (WS2)', 'Random Forest'],
    'Readmissions': [cm_test_best_ws1[1, 0], cm_test_best_ws2[1, 0], cm_test_rf[1, 0]],
    'Interventions': [interventions_ws1, interventions_ws2, interventions_rf],
    'Cost ($)': [cost_ws1, cost_ws2, cost_rf]
}

df_cost_comparison = pd.DataFrame(data)
print(df_cost_comparison.to_string(index=False))
# Out:
#                     Model  Readmissions  Interventions  Cost ($)
# Logistic Regression (WS1)           100           2528   9084000
# Logistic Regression (WS2)           287           2197  10896000
#             Random Forest            68           2494   8502000

# %% [markdown]
# If we can use more models, we can employ an ensemble method via VotingClassifier() to combine the predictions from multiple models and potentially increase the accuracy and stability of the results.
#
# Here, I tested combining the models from Question 4 (Logistic Regression with Elastic Net Regularization) and Question 6 (Random Forest) using the VotingClassifier. The results were slightly worse than the Random Forest model alone. This may be because there are only two models in the ensemble, and VotingClassifier is more effective when combining the predictions of a diverse set of models. In this case, the ensemble method may average out the strengths of each model, resulting in less pronounced improvements.

# %% [markdown]
# Following codes are just for test and fun, not include in answer of Question 8.

# %%
# Define the scaler
scaler = StandardScaler()

# Define the Logistic Regression model with best found parameters
log_reg = LogisticRegression(
    solver='saga',
    max_iter=1000,
    C=10,
    class_weight={1: 0.7, 0: 0.3},
    penalty='elasticnet',
    l1_ratio=0.5,
    random_state=30
)

# Create the pipeline for Logistic Regression
pipeline_log_reg = Pipeline([
    ('scaler', scaler),
    ('log_reg', log_reg)
])

# Define the Random Forest model with best found parameters
rf_clf = RandomForestClassifier(
    n_estimators=150,
    class_weight={1: 0.7, 0: 0.3},
    max_features=20,
    min_samples_split=20,
    random_state=30
)

# No need for scaling in Random Forest, but to keep consistency in naming
pipeline_rf = Pipeline([
    ('scaler', scaler),
    ('rf', rf_clf)
])

# %%
# Create the VotingClassifier with both pipelines
voting_clf = VotingClassifier(
    estimators=[
        ('log_reg', pipeline_log_reg),
        ('rf', pipeline_rf)
    ],
    voting='soft'  # Use soft voting to average probabilities
)

# Train the VotingClassifier
voting_clf.fit(X_train_scaled, y_train)

# Make Predictions and Evaluate
y_pred_train_voting = voting_clf.predict(X_train_scaled)
y_pred_test_voting = voting_clf.predict(X_test_scaled)

# %%
# Evaluate the model
print("Classification Report for Voting Classifier on Test Data:")
print(classification_report(y_test, y_pred_test_voting))

# Confusion Matrix for the training set
cm_train_voting = confusion_matrix(y_true=y_train, y_pred=y_pred_train_voting)
# Confusion Matrix for the test set
cm_test_voting = confusion_matrix(y_true=y_test, y_pred=y_pred_test_voting)

# Plot the confusion matrices using the provided function
plot_confusion_matrix(cm_train_voting, 'Training', 'Voting Classifier')
plot_confusion_matrix(cm_test_voting, 'Test', 'Voting Classifier')
# Out:
# Classification Report for Voting Classifier on Test Data:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99     11470
#            1       0.92      0.97      0.94      2384
#
#     accuracy                           0.98     13854
#    macro avg       0.95      0.97      0.96     13854
# weighted avg       0.98      0.98      0.98     13854

# %% [markdown]
# ---

# %% [markdown]
# © 2024 Copyright The University of New South Wales - CRICOS 00098G
