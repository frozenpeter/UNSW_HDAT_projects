# %% [markdown]
# ![alt text](https://drive.google.com/uc?export=view&id=1DXUVHxd4t15mfuqMgMCLnsP4jWVI5EWz)
# <br>
# © Copyright The University of New South Wales - CRICOS 00098G

# %% [markdown]
# ---

# %% [markdown]
# # Laboratory 1

# %% [markdown]
# In this first laboratory session, we will go through steps 1-4 of the health data science workflow (see  the image with the 10 steps below).
#
# Amongst other things, we will:
# 1.   Become familiar with the diabetes hospitalizations - [inpatient hospital dataset](https://unsw-my.sharepoint.com/:x:/g/personal/z3368601_ad_unsw_edu_au/ESzmxL4_BH1Ds5OryTIFE-gB-lg1B5CQc9FdWrE_gBOtug?e=aeOpfd) and the clinical terms contained within it. Password: HDAT9500-Material
# 2.   Become familiar with the [data dictionary](https://unsw-my.sharepoint.com/:b:/g/personal/z3368601_ad_unsw_edu_au/EUMmCMCex59Chi3b70buY1EBsFPgmWmamYdDfzEYdVRn2Q?e=cfoOKP) - Password: HDAT9500-Material
# 3. Compute basic statistics of our data.
# 4. Visualize and explore our data, particularly how our input data relates to the output.
# 5. Clean our data.

# %% [markdown]
# ![alt text](https://drive.google.com/uc?export=view&id=105SGqeyo8RgLhSO8mN7ZE5OsG0YiLPKt)

# %% [markdown]
# Google Cloud Tech has a very nice [video](https://www.youtube.com/watch?v=nKW8Ndu7Mjw&list=PLIivdWyY5sqJxnwJhe3etaK7utrBiPBQ2) in which they explain [their 7 steps of machine learning](https://www.youtube.com/watch?v=nKW8Ndu7Mjw&list=PLIivdWyY5sqJxnwJhe3etaK7utrBiPBQ2).
#
# By the end of the course, you will be able to create your own workflow with as many steps as you consider relevant. I'll be happy to hear your proposal.

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 1. Step 1: Question - Research Question - Health or Healthcare related question
#
#
# *  What is the research question?
# *   What type of health data science problem is it? E.g. description, prediction or classification, or causal inference.
# *   How is the system going to be used? What exactly is the business/healthcare institution objective? How are they going to be benefited from this model?
# * Do we need machine learning algorithms? Is answering this question useful? Are we replacing any existing technique?

# %% [markdown]
# <b> Write your answer/thoughts here:</b>
# ################################################################################
#
# (double-click here)
#
#
# ################################################################################

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 2. Step 2: Do we have the data to answer this question?

# %% [markdown]
# <b> Write your answer/thoughts here:</b>
# ################################################################################
#
# (double-click here)
#
#
# ################################################################################

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 3. Step 3: Data Gathering

# %% [markdown]
# <b> Write your answer/thoughts here:</b>
# ################################################################################
#
# (double-click here)
#
#
# ################################################################################

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Data Dictionary
# Check the [data dictionary](https://unsw-my.sharepoint.com/:b:/g/personal/z3368601_ad_unsw_edu_au/EUMmCMCex59Chi3b70buY1EBsFPgmWmamYdDfzEYdVRn2Q?e=cfoOKP).
#
# Let's have the data dictionary present throughout the whole exercise.

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Prologue
# The text inside these boxes is "markdown". To learn how to write using markdown, check the API:
# https://www.markdownguide.org/cheat-sheet/
#
# ## General Information:
#
# **Purpose:** xx
#
# **Author**: yy
#
# **Date 1**: zz
#
# **Date 2**: zz
#
# **Description**: rr

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Variable and Constant Declarations
#
# **== Variables ==**
#
# For _setup directory_
#
# * `root` file path for google drive
# * `project_path` file path for project data, output, notebook etc
#
# For _dataset preparation_ (i.e. feature/target and train/test)
# - `path_csv` path where the CSV file is contained
# - `hospital` pandas DataFrame object contains original data
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Function/Method Documentation:
#
# ## Libraries
# 1. pandas:
#   a. API reference for pandas: https://pandas.pydata.org/docs/reference/index.html
#  API stands for Application Programming Interface. An API is essentially a set of instructions or a "how-to" guide for using a particular software. It also contains examples.
#
#   b. What is pandas? "When working with tabular data, such as data stored in spreadsheets or databases, pandas is the right tool for you. pandas will help you to explore, clean, and process your data. In pandas, a data table is called a DataFrame." source: API reference for pandas.
# 2. ss

# %%
# Pandas' API: https://www.google.com/url?q=https%3A%2F%2Fpandas.pydata.org%2Fdocs%2Freference%2Findex.html
import pandas as pd
# Seaborn: https://seaborn.pydata.org/index.html
import seaborn as sns

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 4. Step 4: Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Preliminary step: Python Version
# It is important to know, as some packages work for one version and may stop working for the next one.

# %%
# check python version
import sys
print('Current python version: ', sys.version)
# Out:
# Current python version:  3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]

# %% [markdown]
# ## Mount Google Drive

# %%
# Mount Google Drive
# We do not need to run this cell if you are not running this notebook in Google Colab
if 'google.colab' in str(get_ipython()):
    from google.colab import drive # import drive from Gogle colab
    root = '/content/drive'     # default location for the drive
    print(root)                 # print content of ROOT (Optional)
    drive.mount(root)
else:
    print('Not running on CoLab')
# Out:
# /content/drive
# Mounted at /content/drive

# %%
# Sanity check
print(get_ipython())

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
from pathlib import Path
if 'google.colab' in str(get_ipython()):
    # EDIT THE PROJECT PATH BELOW IF DIFFERENT FROM YOURS
    # In my case, I have all my notebooks for this course inside the folder
    # 'Colab Notebooks' that Google Colab provides by default
    project_path = Path(root) / 'MyDrive' / 'Colab Notebooks'

    # OPTIONAL - set working directory according to your google drive project path
    # import os
    # Change directory to the location defined in project_path
    # os.chdir(project_path)
else:
    project_path = Path(root) / 'MyDrive' / 'Colab Notebooks' / 'Week 1'

# %%
from pathlib import Path
project_path = '/content/drive/My Drive/Colab Notebooks/Week 1'
path_csv = Path(project_path) / 'diabetes/diabetes.csv'

# %%
# (Insert comment here if you would like to add more information)
# Change the path accordingly to your own path. If the path is taken from Google Drive or your local folder:
path_csv = Path(project_path) /'diabetes.csv'
# Pandas' API, section Input/Output: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
hospital = pd.read_csv(path_csv,sep=',')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-29-b72d4d4ba8ef> in <cell line: 5>()
#       3 path_csv = Path(project_path) /'diabetes.csv'
#       4 # Pandas' API, section Input/Output: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
# ----> 5 hospital = pd.read_csv(path_csv,sep=',')
#
# ...

# %%
# Alternative code
# %cd /content/drive/My Drive/Colab Notebooks/
# hospital = pd.read_csv("diabetes.csv")

# %%
# (Insert comment here if you would like to add more information)
# Pandas' API, section Dataframe: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html
hospital.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-f9bbec6832d4> in <cell line: 3>()
#       1 # (Insert comment here if you would like to add more information)
#       2 # Pandas' API, section Dataframe: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html
# ----> 3 hospital.head()
#
# NameError: name 'hospital' is not defined

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Load the data and check its dimensions
#
# 1. Let us print the name of each column.
# 2. Let us print the dimenstions of the dataframe (number of **indexes** (or rows), number of **columns/features**),

# %%
# (Insert comment here if you would like to add more information)
# Print the columns/features names of our dataset using 'pd.columns'.
# Pandas' API, section Dataframe: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.columns.html
print("Features of hospital data:", hospital.columns)

# Print the number of rows and columns using 'pd.shape':
# Pandas' API, section Dataframe: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shape.html
print("Number of rows and columns: ", hospital.shape)
# Out:
# Features of hospital data: Index(['admission_type_id', 'admission_source_id', 'patient_id', 'los', 'Age',
#        'admission_id', 'sex', 'weight', 'discharge_disposition_id',
#        'payer_code', 'medical_specialty', 'max_glu_serum', 'A1Cresult',
#        'number_diagnoses', 'num_lab_procedures', 'num_procedures',
#        'num_medications', 'number_emergency', 'number_inpatient',
#        'number_outpatient', 'group_name_1', 'group_name_2', 'group_name_3',
#        'readmission'],
#       dtype='object')
# Number of rows and columns:  (69276, 24)

# %% [markdown]
# **Note:** 'los' stands for length of stay. Time in hospital or number of days between admission and discharge.
# Please see Table 1, page 3 of the paper: http://dx.doi.org/10.1155/2014/781670

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ##  Redundant features

# %% [markdown]
# Are there any redundant columns/features?

# %%
hospital.head()
# Out:
#    admission_type_id  admission_source_id  patient_id  los  Age  admission_id  \
# 0                  3                    7      360576    2   79      62781276
# 1                  3                    7     8151831    5   59      49223976
# 2                  3                    7    90219069    2   33     210634308
# 3                  3                    7    54294840    6   42     163620402
# 4                  3                    7     1634688    1   62      69055020
#
#       sex weight  discharge_disposition_id payer_code  ... num_lab_procedures  \
# 0  Female      ?                        18          ?  ...                 38
# 1    Male      ?                         1          ?  ...                 49
# 2  Female      ?                         1         MD  ...                 62
# 3  Female      ?                         6          ?  ...                 77
# 4    Male      ?                         1          ?  ...                 13
#
# ...

# %%
# Pandas' API: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.duplicated.html
hospital.duplicated(subset=['patient_id'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 69271    False
# 69272    False
# 69273    False
# 69274    False
# 69275    False
# Length: 69276, dtype: bool

# %%
# Let's sum
sum(hospital.duplicated(subset=['patient_id']))
# Out:
# 0

# %% [markdown]
# For prediction purposes, we are not interested in the first two columns (admission_id and patient_id), which are just identifiers. Therefore, we will drop these variables from our dataset. Python command: "DataFrame.drop([column names],axis=1)"
#
# More information: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html

# %%
# (Insert comment here if you would like to add more information)
# Python command to drop variables: DataFrame.drop([column selection], axis=1)
# Pandas' API, section Dataframe: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html

# We drop 'admission_id' and 'patient_id' by using the command: DataFrame.drop([column selection], axis=1)
hospital = hospital.drop(['admission_id', 'patient_id'], axis =1)

# %%
# Sanity check
hospital.head()
# Out:
#    admission_type_id  admission_source_id  los  Age     sex weight  \
# 0                  3                    7    2   79  Female      ?
# 1                  3                    7    5   59    Male      ?
# 2                  3                    7    2   33  Female      ?
# 3                  3                    7    6   42  Female      ?
# 4                  3                    7    1   62    Male      ?
#
#    discharge_disposition_id payer_code medical_specialty max_glu_serum  ...  \
# 0                        18          ?                 ?           NaN  ...
# 1                         1          ?       Pulmonology           NaN  ...
# 2                         1         MD                 ?           NaN  ...
# 3                         6          ?                 ?           NaN  ...
# 4                         1          ?        Cardiology           NaN  ...
#
#   num_lab_procedures  num_procedures  num_medications  number_emergency  \
# ...

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Nature of the features
#
# Let's use the Python command **"DataFrame.dtypes"** to check if our variables are continuous or categorical and if they are aligned with the Data Dictionary.

# %%
# (Insert comment here if you would like to add more information)
# Checking the nature of our variables in Python
# Pandas' API, section Dataframe: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dtypes.html
hospital.dtypes
# Out:
# admission_type_id            int64
# admission_source_id          int64
# los                          int64
# Age                          int64
# sex                         object
# weight                      object
# discharge_disposition_id     int64
# payer_code                  object
# medical_specialty           object
# max_glu_serum               object
# A1Cresult                   object
# number_diagnoses             int64
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_emergency             int64
# number_inpatient             int64
# number_outpatient            int64
# group_name_1                object
# group_name_2                object
# group_name_3                object
# readmission                 object
# dtype: object

# %% [markdown]
# **Make sure you understand which variables are <font color=green>continuous</font> and which ones are <font color=green>categorical or nominal</font>, and determine if this is appropriate or if adjustments are needed.**

# %% [markdown]
# We can see that the variables 'admission_type_id', 'discharge_disposition_id' and 'admission_source_id' are continuous in our dataset. However, according to the Data Dictionary, these variables should be categorical.
#
# **Let's transform the variables 'admission_type_id', 'discharge_disposition_id' and 'admission_source_id' from continuous to categorical** (please note that regarding the data dictionary, these variables are categorical and not numerical).
#
# For this, we will create new variables: 'admission_type_id_cat', 'discharge_disposition_id_cat' and 'admission_source_id_cat'.

# %%
# (Insert comment here if you would like to add more information)
# Pandas' API, section Dataframe: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html
hospital[['admission_type_id_cat','discharge_disposition_id_cat','admission_source_id_cat']] = hospital[['admission_type_id','discharge_disposition_id','admission_source_id' ]].astype('category')

# %% [markdown]
# Now that all the variables in our dataset are aligned with the Data Dictionary, we will drop the old variables 'admission_type_id', 'discharge_disposition_id' and 'admission_source_id'.

# %%
# (Insert comment here if you would like to add more information)
# Python command to drop variables: DataFrame.drop([column selection], axis=1)
# Pandas' API, section Dataframe: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html
hospital = hospital.drop(['admission_type_id','discharge_disposition_id','admission_source_id'],axis=1)

# %%
# Check
hospital.dtypes
# Out:
# los                                int64
# Age                                int64
# sex                               object
# weight                            object
# payer_code                        object
# medical_specialty                 object
# max_glu_serum                     object
# A1Cresult                         object
# number_diagnoses                   int64
# num_lab_procedures                 int64
# num_procedures                     int64
# num_medications                    int64
# number_emergency                   int64
# number_inpatient                   int64
# number_outpatient                  int64
# group_name_1                      object
# group_name_2                      object
# group_name_3                      object
# readmission                       object
# admission_type_id_cat           category
# discharge_disposition_id_cat    category
# admission_source_id_cat         category
# dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Column selection
#
# We select some of the columns to **look at our data**.
#
# * **DataFrame.iloc**: Purely integer-location based indexing for selection by position (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html)
#
# We use **iloc** to access specific records and columns, by using the command: **DataFrame.iloc[row selection, colummn selection]** (Source:https://www.shanelynn.ie/select-pandas-dataframe-rows-and-columns-using-iloc-loc-and-ix/)

# %%
# DataFrame.iloc[row selection,column selection]
print(hospital.iloc[0:20,0:5])   # Selecting the first 20 rows and columns 0 to 5 from 'hospital' data
# Out:
#     los  Age     sex weight payer_code
# 0     2   79  Female      ?          ?
# 1     5   59    Male      ?          ?
# 2     2   33  Female      ?         MD
# 3     6   42  Female      ?          ?
# 4     1   62    Male      ?          ?
# 5     1   53  Female      ?         HM
# 6    10   80  Female      ?          ?
# 7     2   44    Male      ?          ?
# 8     1   73    Male      ?         MC
# 9     4   64  Female      ?          ?
# 10    4   61  Female      ?          ?
# 11    7   65  Female      ?          ?
# 12    4   86    Male      ?         MC
# 13    1   52  Female      ?         SP
# 14    2   58  Female      ?          ?
# 15    3   84  Female      ?          ?
# 16    3   69    Male      ?         OG
# 17    2   57    Male      ?          ?
# 18    2   43    Male      ?         OG
# 19    4   80  Female      ?         MC

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Row selection

# %% [markdown]
# * **DataFrame.loc**: The *loc* indexer can be used to select rows by label/index or to select rows with a boolean/conditional lookup (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html)
#
# As the *iloc* indexer, the command of **loc** is: **DataFrame.loc[row selection, colummn selection]** (Source:https://www.shanelynn.ie/select-pandas-dataframe-rows-and-columns-using-iloc-loc-and-ix/)

# %%
# DataFrame.loc[row selection,column selection]
print(hospital.loc[0:20,'sex':'medical_specialty']) #Selecting the first 20 rows for columns 'sex' to 'medical_specialty'
# Out:
#        sex weight payer_code medical_specialty
# 0   Female      ?          ?                 ?
# 1     Male      ?          ?       Pulmonology
# 2   Female      ?         MD                 ?
# 3   Female      ?          ?                 ?
# 4     Male      ?          ?        Cardiology
# 5   Female      ?         HM                 ?
# 6   Female      ?          ?        Nephrology
# 7     Male      ?          ?           Urology
# 8     Male      ?         MC                 ?
# 9   Female      ?          ?       Orthopedics
# 10  Female      ?          ?                 ?
# 11  Female      ?          ?                 ?
# 12    Male      ?         MC                 ?
# 13  Female      ?         SP  InternalMedicine
# 14  Female      ?          ?                 ?
# 15  Female      ?          ?  InternalMedicine
# 16    Male      ?         OG  Emergency/Trauma
# 17    Male      ?          ?                 ?
# 18    Male      ?         OG                 ?
# ...

# %% [markdown]
# Missing values can be observed for the variables 'weight', 'payer_code' and 'medical_specialty'. We will explore our dataset in greater depth in the following steps.

# %% [markdown]
# ---

# %% [markdown]
# ---
